# %% [markdown]
# ## Python data structures and boolean
# 1.boolean
# 2.boolean and logical operators
# 3.lists
# 4.comparison operators
# 5.dictionaries
# 6.tuples
# 7.sets

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
my_str = "Geethac12"
print(my_str.isalnum()) # check if numbers
print(my_str.isalpha()) # IF ALL are alphabets or not
print(my_str.isdigit()) # does it digits only
print(my_str.istitle()) # first letter is capital or not
print(my_str.islower()) # lower case
print(my_str.isupper()) # upper case
print(my_str.endswith("2")) #
print(my_str.startswith("G")) #
# Out:
# True
# False
# False
# True
# False
# False
# True
# True

# %% [markdown]
# ## Boolean and logical Operators

# %% [markdown]
# ### gates = or,and,not,(nor,nand,xor,xnor)

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
example = "hello world"
my_str = 'jane'
example.isdigit() or my_str.isalpha()
example.isdigit() and my_str.isalpha()
# Out:
# False

# %% [markdown]
# # list

# %% [markdown]
# #### is mutable or changeable,ordered sequence. each element inside of list is called an item lists are defined by having values between sqaure brackets[]

# %%
lst_example=['hello',3,5,6,7]
type(lst_example)
len(lst_example)
# Out:
# 5

# %%
lst = list() # inbuilt

# %%
lst = ["apple",'hello',20,30,40]

# %% [markdown]
# ##### Append

# %%
lst.append("ball")
print(lst)
# Out:
# ['apple', 'hello', 20, 30, 40, 'ball']

# %%
lst.append(["john",'bay'])

# %%
## Indexing in list
lst[2:5]
# Out:
# [20, 30, 40]

# %% [markdown]
# #### Insert

# %%
lst.insert(2,"now")

# %%
lst
# Out:
# ['apple', 'hello', 'now', 20, 30, 40, 'ball', ['john', 'bay']]

# %% [markdown]
# #### Extend method

# %%
lst= [1,2,3,4,5,6]
lst.extend([7,8])
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ### Various operations that we can perform in list

# %%
lst = [1,2,3,4,5]

# %%
sum(lst)
# Out:
# 15

# %%
lst*3
# Out:
# [1, 2, 3, 4, 5, 6, 1, 1, 1, 2, 3, 4, 5, 6, 1, 1, 1, 2, 3, 4, 5, 6, 1, 1]

# %% [markdown]
# ### Pop Method

# %%
lst.pop()
# Out:
# 5

# %%
lst.pop(1)
# Out:
# 2

# %%
lst
# Out:
# [1, 3, 4]

# %% [markdown]
# #### Count():Calculates total occurance ofa given element of list

# %%
lst = [1,2,3,4,5,6,1,1]
lst.count(1)
# Out:
# 3

# %%
len(lst)
# Out:
# 8

# %%
lst.index(4,1,4) # returns the index of first occurance . Start and end index are not neccary
# Out:
# 3

# %%
# Min and Max
min(lst)
# Out:
# 1

# %%
max(lst)
# Out:
# 6
